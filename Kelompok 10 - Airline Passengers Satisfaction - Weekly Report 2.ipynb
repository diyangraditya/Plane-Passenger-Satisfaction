# %% [markdown]
# # AIRLINE PASSENGER SATISFACTION
# ___
#
#
# # Kelompok 10
#
# ## BCC Data Science Intern 2024
#
# - Diyang Raditya Anwar (225150407111037)
# - Muhammad Omar Haqqi (235150219111001)

# %% [markdown]
# ## Import Necessary Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('datasets/train.csv')
df.iloc[:, 0:20].head(10)
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
# 5           5  111157  Female     Loyal Customer   26  Personal Travel
# 6           6   82113    Male     Loyal Customer   47  Personal Travel
# 7           7   96462  Female     Loyal Customer   52  Business travel
# 8           8   79485  Female     Loyal Customer   41  Business travel
# 9           9   65725    Male  disloyal Customer   20  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# ...

# %%
df.iloc[:, 20:25].head(10)
# Out:
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
# 5                 4            1                           0
# 6                 5            2                           9
# 7                 5            4                           4
# 8                 1            2                           0
# 9                 3            2                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0             id            Age  Flight Distance  \
# count  103904.000000  103904.000000  103904.000000    103904.000000
# mean    51951.500000   64924.210502      39.379706      1189.448375
# std     29994.645522   37463.812252      15.114964       997.147281
# min         0.000000       1.000000       7.000000        31.000000
# 25%     25975.750000   32533.750000      27.000000       414.000000
# 50%     51951.500000   64856.500000      40.000000       843.000000
# 75%     77927.250000   97368.250000      51.000000      1743.000000
# max    103903.000000  129880.000000      85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103904.000000                      103904.000000
# mean                2.729683                           3.060296
# std                 1.327829                           1.525075
# min                 0.000000                           0.000000
# ...

# %%
df.shape
# Out:
# (103904, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Unnamed: 0                         103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Customer Type                      103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Type of Travel                     103904 non-null  object
#  6   Class                              103904 non-null  object
#  7   Flight Distance                    103904 non-null  int64
#  8   Inflight wifi service              103904 non-null  int64
#  9   Departure/Arrival time convenient  103904 non-null  int64
#  10  Ease of Online booking             103904 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                             0
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data cleaning

# %%
df_new = df.drop(['Unnamed: 0'], axis=1)
df_new.head(10)
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
# 5  111157  Female     Loyal Customer   26  Personal Travel       Eco
# 6   82113    Male     Loyal Customer   47  Personal Travel       Eco
# 7   96462  Female     Loyal Customer   52  Business travel  Business
# 8   79485  Female     Loyal Customer   41  Business travel  Business
# 9   65725    Male  disloyal Customer   20  Business travel       Eco
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# ...

# %%
df_new1 = df_new

# %%
df_new1["Arrival Delay in Minutes"].mean()
# Out:
# 15.178678301832152

# %%
df_new1["Arrival Delay in Minutes"] = df_new1["Arrival Delay in Minutes"].fillna(df_new1["Arrival Delay in Minutes"].mean())
## Mengisi value yang kosong

# %%
df_new1["Arrival Delay in Minutes"].mean()
# Out:
# 15.1786783018322

# %%
df_new1.isna().sum()
# Out:
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Categorical Columns

# %%
var_cat = df_new1.select_dtypes(include=["object"]).columns
print(var_cat)
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction'], dtype='object')

# %%
plt.style.use("ggplot")
warna_warna = sns.color_palette("husl")

for col_name in var_cat:
    plt.figure(figsize=(20,4))
    plt.subplot(121)
    col = df_aja[col_name].value_counts()
    col.plot(kind="bar", color=warna_warna)
    plt.xlabel(col_name)
    plt.ylabel("Number of customer")
    plt.xticks(rotation=0)
    plt.title(col_name)
    for i, val in enumerate(col):
        plt.text(i, val + 0.1, str(val), ha='center')

# %% [markdown]
# Berdasarkan grafik di atas, kita dapat melihat jumlah nilai dari suatu kolom
# 1. Gender
#     - Male = 51,177
#     - Female = 52,727
# 2. Customer Type
#     - Loyal Customer = 84,923
#     - Disloyal Customer = 18,981
# 3. Type of Travel
#     - Business Travel = 71,655
#     - Personal Travel = 32,249
# 4. Class
#     - Business = 49,665
#     - Eco = 46,745
#     - Eco Plus = 7,494
# 5. Satisfaction
#     - Neutral or dissatisfied = 58,879
#     - Satisfied = 45,025

# %%
fig, ax = plt.subplots()
Gen_pie = df["Gender"].value_counts()
Gen_pie_a = Gen_pie.index
ax.pie(Gen_pie, labels=Gen_pie_a, autopct='%2.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x15820cf5fd0>,
# ...
#  [Text(-0.025773424500537056, 1.0996980179074232, 'Female'),
#   Text(0.02577342450053692, -1.0996980179074232, 'Male')],
#  [Text(-0.014058231545747483, 0.5998352824949581, '50.75%'),
#   Text(0.01405823154574741, -0.5998352824949581, '49.25%')])

# %%
gender_counts = df_aja["Gender"].value_counts()
ax = gender_counts.plot(kind="bar")
for i, val in enumerate(gender_counts):
    plt.text(i, val + 0.1, str(val), ha='center')

plt.xlabel('Gender')
plt.ylabel('Total Passengers')
plt.title('Total Passengers of Each Gender')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Berdasarkan grafik di atas, kita bisa melihat bahwa kolom Gender terdiri dari:
#     - Female = 52,727
#     - Male = 51,177

# %% [markdown]
# ## Numerical columns

# %%
var_sati = ['Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking', 
           'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort', 'Inflight entertainment', 'On-board service'
          , 'Leg room service', 'Baggage handling', 'Checkin service', 'Inflight service', 'Cleanliness']

# %%
plt.style.use("ggplot")
warnaa = sns.color_palette("husl")

plt.figure(figsize=(15,12))

plt.subplot(2, 1, 1)
df_new1["Age"].value_counts().sort_index().plot(kind="bar", color=warnaa)
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Age Passenger Distribution")

plt.subplot(2, 1, 2)
sns.boxplot(y=df_new1["Age"])
plt.title("Age Passenger Distribution")
# Out:
# Text(0.5, 1.0, 'Age Passenger Distribution')

# %% [markdown]
# Berdasarkan grafik di atas, kita dapat melihat bahwa pelanggan sebagian besar penumpang termasuk kategori dewasa (20-60 tahun)

# %%
plt.style.use("ggplot")
wirni_warna = sns.color_palette("husl")

for kolom in var_sati:
    plt.figure(figsize=(12,6))
    counts = df_aja[kolom].value_counts().sort_index()
    counts.plot(kind="bar", color=wirni_warna)
    plt.xlabel(kolom)
    plt.ylabel("Total Passengers")
    plt.xticks(rotation=0)
    plt.title(kolom)
    for i, val in enumerate(counts):
        plt.text(i, val + 0.1, str(val), ha='center')

# %% [markdown]
# Dari grafik-grafik di atas, kita dapat melihat layanan apa saja yang masih kurang memuaskan dan yang sudah memuaskan menurut penumpang dengan melihat jumlah dari nilai 0-5. Jika semakin banyak jumlah angka yang besar maka semakin memuaskan dan begitu juga sebaliknya.

# %%
plt.figure(figsize=(20,22))

plt.subplot(3, 2, 1)
sns.histplot(df_new1["Flight Distance"], edgecolor='black', kde=True)
plt.xlabel("Flight Distance")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.title("Flight Distance Chart")

plt.subplot(3, 2, 2)
sns.boxplot(y=df_new1["Flight Distance"])
plt.title("Flight Distance chart")

plt.subplot(3, 2, 3)
sns.histplot(df_new1["Departure Delay in Minutes"], bins=40, edgecolor='black', kde=True)
plt.xlabel("Departure Delay in Miinutes")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.title("Departure Delay in Minutes")

plt.subplot(3, 2, 4)
sns.boxplot(y=df_new1["Departure Delay in Minutes"])
plt.title("Departure Delay in Minutes")

plt.subplot(3, 2, 5)
sns.histplot(df_new1["Arrival Delay in Minutes"], bins=40, edgecolor='black', kde=True)
plt.xlabel("Arrival Delay in Miinutes")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.title("Arrival Delay in Minutes")

plt.subplot(3, 2, 6)
sns.boxplot(y=df_new1["Arrival Delay in Minutes"])
plt.title("Arrival Delay in Minutes")
# Out:
# Text(0.5, 1.0, 'Arrival Delay in Minutes')

# %%
sns.scatterplot(x=df_new1["Arrival Delay in Minutes"], y=df_new1["Departure Delay in Minutes"], data=df_new)
# Out:
# <Axes: xlabel='Arrival Delay in Minutes', ylabel='Departure Delay in Minutes'>

# %% [markdown]
# Dari grafik-grafik di atas, kita dapat melihat bahwa kolom 'Departure Delay in Minutes' memiliki korelasi dengan 'Arrival Delay in Minutes'. Semakin besar 'Departure Delay in Minutes'nya semakin besar juga 'Arrival Delay in Minutes'nya.

# %% [markdown]
# #### Menambahkan kolom kategori umur ke datasets

# %%
batas = [0, 12, 20, 60, float('inf')]
kateg = ['Child', 'Teenager', 'Adult', 'Elder']
df_new1['Age Category'] = pd.cut(df_new1['Age'], bins=batas, labels=kateg, right=False)
kol_catage = df_new1.pop('Age Category')
df_new1.insert(loc=4, column='Age Category', value=kol_catage)
df_new1.head()
# Out:
#        id  Gender      Customer Type  Age Age Category   Type of Travel  \
# 0   70172    Male     Loyal Customer   13     Teenager  Personal Travel
# 1    5047    Male  disloyal Customer   25        Adult  Business travel
# 2  110028  Female     Loyal Customer   26        Adult  Business travel
# 3   24026  Female     Loyal Customer   25        Adult  Business travel
# 4  119299    Male     Loyal Customer   61        Elder  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  2  ...                       1
# ...

# %% [markdown]
# ## Melihat kepuasan berdasarkan kategori usia

# %%
child = df_new1.loc[df_new1['Age Category'] == 'Child']
teenager = df_new1.loc[df_new1['Age Category'] == 'Teenager']
adult = df_new1.loc[df_new1['Age Category'] == 'Adult']
old = df_new1.loc[df_new1['Age Category'] == 'Elder']

# %%
plt.style.use("ggplot")
wirni_warna = sns.color_palette("husl")
child['satisfaction'].value_counts().plot(kind="bar", color=wirni_warna)
plt.title('Satisfaction of Child')
plt.xticks(rotation=0)
for i, val in enumerate(child['satisfaction'].value_counts()):
    plt.text(i, val + 0.1, int(val), ha='center')

# %%
plt.style.use("ggplot")
wirni_warna = sns.color_palette("husl")
teenager['satisfaction'].value_counts().plot(kind="bar", color=wirni_warna)
plt.title('Satisfaction of Teenager')
plt.xticks(rotation=0)
for i, val in enumerate(teenager['satisfaction'].value_counts()):
    plt.text(i, val + 0.1, int(val), ha='center')

# %%
plt.style.use("ggplot")
wirni_warna = sns.color_palette("husl")
adult['satisfaction'].value_counts().plot(kind="bar", color=wirni_warna)
plt.title('Satisfaction of Adult')
plt.xticks(rotation=0)
for i, val in enumerate(adult['satisfaction'].value_counts()):
    plt.text(i, val + 0.1, int(val), ha='center')

# %%
plt.style.use("ggplot")
wirni_warna = sns.color_palette("husl")
old['satisfaction'].value_counts().plot(kind="bar", color=wirni_warna)
plt.title('Satisfaction of Elder')
plt.xticks(rotation=0)
for i, val in enumerate(old['satisfaction'].value_counts()):
    plt.text(i, val + 0.1, int(val), ha='center')

# %% [markdown]
# Berdasarkan grafik-grafik di atas, kita bisa melihat berapa banyak penumpang yang puas dan penumbang yang kurang puas berdasarkan kategori umur penumpang
#    1. Child
#         - Puas = 419
#         - Kurang puas = 2,836
#    2. Teenager
#         - Puas = 1,342
#         - Kurang puas = 5,216
#    3. Adult
#         - Puas = 40,628
#         - Kurang puas = 43,744
#    4. Elder
#         - Puas = 2,636
#         - Kurang puas = 7,083

# %% [markdown]
# ### Mencari faktor-faktor yang mempengaruhi satisfied

# %%
satis = df1.loc[df1['satisfaction'] == 'satisfied']
neutral = df1.loc[df1['satisfaction'] == 'neutral or dissatisfied']

# %%
kolom = df1[['Inflight wifi service',
       'Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
       'Inflight entertainment', 'On-board service', 'Leg room service',
       'Baggage handling', 'Checkin service', 'Inflight service',
       'Cleanliness']]
kolom['Satisfaction 01'] = df1['satisfaction'].map({'satisfied': 1, 'neutral or dissatisfied': 0})
kolom.head()
# Out:
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 0                       3              1               5                3
# 1                       3              3               1                3
# 2                       2              2               5                5
# 3                       5              5               2                2
# 4                       3              3               4                5
#
#    Seat comfort  Inflight entertainment  On-board service  Leg room service  \
# 0             5                       5                 4                 3
# ...

# %%
corr_col = kolom.corr()
plt.figure(figsize=(8, 6));
sns.heatmap(corr_col, annot=True, annot_kws={"size": 7})
# Out:
# <Axes: >

# %% [markdown]
# ## Bivariate Analysis

# %%
df_aja = df_new1

plt.style.use("ggplot")
wir = sns.color_palette("husl")

plt.figure(figsize=(12,8))
sns.countplot(data=df_aja, x= df_aja["Age Category"], hue=df_aja["satisfaction"])
plt.xlabel("Test")
plt.ylabel("Count")
plt.title("Satisfaction Chart by Age Category")
# Out:
# Text(0.5, 1.0, 'Satisfaction Chart by Age Category')

# %%
economy = df_aja.loc[df_aja['Class'] == 'Eco']
economy_Plus = df_aja.loc[df_aja['Class'] == 'Eco Plus']
business = df_aja.loc[df_aja['Class'] == 'Business']

# %%
plt.style.use('ggplot')
plt.figure(figsize=(15,8))
warnacuy = sns.color_palette('husl')

plt.subplot(1, 3, 1)
economy['satisfaction'].value_counts().plot(kind='bar', color=warnacuy)
plt.title('Satisfaction of Eco Class')
plt.xticks(rotation=0)
plt.ylabel("Total Passengers")
plt.xlabel("Economy Class")
for i, val in enumerate(economy['satisfaction'].value_counts()):
    plt.text(i, val + 0.1, int(val), ha='center')


plt.subplot(1, 3, 2)
economy_Plus['satisfaction'].value_counts().plot(kind='bar', color=warnacuy)
plt.title('Satisfaction of Economy Pluss Class')
plt.xticks(rotation=0)
plt.ylabel("Total Passengers")
plt.xlabel("Economy Plus Class")
for i, val in enumerate(economy_Plus['satisfaction'].value_counts()):
    plt.text(i, val + 0.1, int(val), ha='center')

plt.subplot(1, 3, 3)
business['satisfaction'].value_counts().sort_index().plot(kind='bar', color=warnacuy)
plt.title('Satisfaction of Business Class')
plt.ylabel("Total Passengers")
plt.xlabel("Business Class")
plt.xticks(rotation=0)
for i, val in enumerate(business['satisfaction'].value_counts()):
    plt.text(i, val + 0.1, int(val), ha='center')

# %% [markdown]
# Jadi bisa disimpulkan sebagian besar penumpang kelas bisnis puas dengan pelayanan maskapainya. Sedangkan penumpang kelas ekonomi dan ekonomi plus sebagian besar tidak puas dengan pelayanan maskapainya. markicau (mario kita cari tau)

# %% [markdown]
# ### Mencari tau kenapa di ekonomi class banyak yang biasa aja / kurang puas

# %%
plt.style.use("ggplot")
warnacuy = sns.color_palette('husl')
plt.figure(figsize=(20,40))

plt.subplot(7, 2, 1)
sns.countplot(x="Leg room service", hue="satisfaction", data=economy, palette=warnacuy)
plt.xlabel("Leg Room Service")
plt.ylabel("Count")
plt.title("Satisfaction by Leg Room Service in Economy Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 2)
sns.countplot(x="Inflight wifi service", hue="satisfaction", data=economy, palette=warnacuy)
plt.xlabel("Inflight wifi service")
plt.ylabel("Count")
plt.title("Satisfaction by Inflight wifi service in Economy Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 3)
sns.countplot(x="Departure/Arrival time convenient", hue="satisfaction", data=economy, palette=warnacuy)
plt.xlabel("Departure/Arrival time convenient")
plt.ylabel("Count")
plt.title("Satisfaction by Departure/Arrival time convenient in Economy Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 4)
sns.countplot(x="Ease of Online booking", hue="satisfaction", data=economy, palette=warnacuy)
plt.xlabel("Ease of Online booking")
plt.ylabel("Count")
plt.title("Satisfaction byEase of Online booking in Economy Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 5)
sns.countplot(x="Gate location", hue="satisfaction", data=economy, palette=warnacuy)
plt.xlabel("Gate location")
plt.ylabel("Count")
plt.title("Satisfaction by Gate location in Economy Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 6)
sns.countplot(x="Food and drink", hue="satisfaction", data=economy, palette=warnacuy)
plt.xlabel("Food and drink")
plt.ylabel("Count")
plt.title("Satisfaction by Food and drink in Economy Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 7)
sns.countplot(x="Online boarding", hue="satisfaction", data=economy, palette=warnacuy)
plt.xlabel("Online boarding")
plt.ylabel("Count")
plt.title("Satisfaction by Online boarding in Economy Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 8)
sns.countplot(x="Seat comfort", hue="satisfaction", data=economy, palette=warnacuy)
plt.xlabel("Seat comfort")
plt.ylabel("Count")
plt.title("Satisfaction by Seat comfort in Economy Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 9)
sns.countplot(x="Inflight entertainment", hue="satisfaction", data=economy, palette=warnacuy)
plt.xlabel("Inflight entertainment")
plt.ylabel("Count")
plt.title("Satisfaction by Inflight entertainment in Economy Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 10)
sns.countplot(x="On-board service", hue="satisfaction", data=economy, palette=warnacuy)
plt.xlabel("On-board service") 
plt.ylabel("Count")
plt.title("Satisfaction by On-board service in Economy Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 11)
sns.countplot(x="Baggage handling", hue="satisfaction", data=economy, palette=warnacuy)
plt.xlabel("Baggage handling") 
plt.ylabel("Count")
plt.title("Satisfaction by Baggage handling in Economy Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 12)
sns.countplot(x="Checkin service", hue="satisfaction", data=economy, palette=warnacuy)
plt.xlabel("Checkin service") 
plt.ylabel("Count")
plt.title("Satisfaction by Checkin service in Economy Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 13)
sns.countplot(x="Inflight service", hue="satisfaction", data=economy, palette=warnacuy)
plt.xlabel("Inflight service") 
plt.ylabel("Count")
plt.title("Satisfaction by Inflight service in Economy Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 14)
sns.countplot(x="Cleanliness", hue="satisfaction", data=economy, palette=warnacuy)
plt.xlabel("Cleanliness") 
plt.ylabel("Count")
plt.title("Satisfaction by Cleanliness in Economy Class")
plt.legend(title='Satisfaction')

# %% [markdown]
# ### Mencari tau kenapa di ekonomi plus class banyak yang biasa aja / kurang puas

# %%
plt.style.use("ggplot")
warnacuy = sns.color_palette('husl')
plt.figure(figsize=(20,40))

plt.subplot(7, 2, 1)
sns.countplot(x="Leg room service", hue="satisfaction", data=economy_Plus, palette=warnacuy)
plt.xlabel("Leg Room Service")
plt.ylabel("Count")
plt.title("Satisfaction by Leg Room Service in Economy PLus Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 2)
sns.countplot(x="Inflight wifi service", hue="satisfaction", data=economy_Plus, palette=warnacuy)
plt.xlabel("Inflight wifi service")
plt.ylabel("Count")
plt.title("Satisfaction by Inflight wifi service in Economy Plus Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 3)
sns.countplot(x="Departure/Arrival time convenient", hue="satisfaction", data=economy_Plus, palette=warnacuy)
plt.xlabel("Departure/Arrival time convenient")
plt.ylabel("Count")
plt.title("Satisfaction by Departure/Arrival time convenient in Economy Plus Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 4)
sns.countplot(x="Ease of Online booking", hue="satisfaction", data=economy_Plus, palette=warnacuy)
plt.xlabel("Ease of Online booking")
plt.ylabel("Count")
plt.title("Satisfaction byEase of Online booking in Economy Plus Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 5)
sns.countplot(x="Gate location", hue="satisfaction", data=economy_Plus, palette=warnacuy)
plt.xlabel("Gate location")
plt.ylabel("Count")
plt.title("Satisfaction by Gate location in Economy PLus Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 6)
sns.countplot(x="Food and drink", hue="satisfaction", data=economy_Plus, palette=warnacuy)
plt.xlabel("Food and drink")
plt.ylabel("Count")
plt.title("Satisfaction by Food and drink in Economy PLus Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 7)
sns.countplot(x="Online boarding", hue="satisfaction", data=economy_Plus, palette=warnacuy)
plt.xlabel("Online boarding")
plt.ylabel("Count")
plt.title("Satisfaction by Online boarding in Economy Plus Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 8)
sns.countplot(x="Seat comfort", hue="satisfaction", data=economy_Plus, palette=warnacuy)
plt.xlabel("Seat comfort")
plt.ylabel("Count")
plt.title("Satisfaction by Seat comfort in Economy PLus Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 9)
sns.countplot(x="Inflight entertainment", hue="satisfaction", data=economy_Plus, palette=warnacuy)
plt.xlabel("Inflight entertainment")
plt.ylabel("Count")
plt.title("Satisfaction by Inflight entertainment in Economy Plus Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 10)
sns.countplot(x="On-board service", hue="satisfaction", data=economy_Plus, palette=warnacuy)
plt.xlabel("On-board service") 
plt.ylabel("Count")
plt.title("Satisfaction by On-board service in Economy Plus Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 11)
sns.countplot(x="Baggage handling", hue="satisfaction", data=economy_Plus, palette=warnacuy)
plt.xlabel("Baggage handling") 
plt.ylabel("Count")
plt.title("Satisfaction by Baggage handling in Economy PLus Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 12)
sns.countplot(x="Checkin service", hue="satisfaction", data=economy_Plus, palette=warnacuy)
plt.xlabel("Checkin service") 
plt.ylabel("Count")
plt.title("Satisfaction by Checkin service in Economy Plus Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 13)
sns.countplot(x="Inflight service", hue="satisfaction", data=economy_Plus, palette=warnacuy)
plt.xlabel("Inflight service") 
plt.ylabel("Count")
plt.title("Satisfaction by Inflight service in Economy Plus Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 14)
sns.countplot(x="Cleanliness", hue="satisfaction", data=economy_Plus, palette=warnacuy)
plt.xlabel("Cleanliness") 
plt.ylabel("Count")
plt.title("Satisfaction by Cleanliness in Economy Plus Class")
plt.legend(title='Satisfaction')

# %% [markdown]
# ### Mencari tau kenapa di business class banyak yang memuaskan

# %%
plt.style.use("ggplot")
warnacuy = sns.color_palette('husl')
plt.figure(figsize=(20,40))

plt.subplot(7, 2, 1)
sns.countplot(x="Leg room service", hue="satisfaction", data=business, palette=warnacuy)
plt.xlabel("Leg Room Service")
plt.ylabel("Count")
plt.title("Satisfaction by Leg Room Service in Business Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 2)
sns.countplot(x="Inflight wifi service", hue="satisfaction", data=business, palette=warnacuy)
plt.xlabel("Inflight wifi service")
plt.ylabel("Count")
plt.title("Satisfaction by Inflight wifi service in Business Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 3)
sns.countplot(x="Departure/Arrival time convenient", hue="satisfaction", data=business, palette=warnacuy)
plt.xlabel("Departure/Arrival time convenient")
plt.ylabel("Count")
plt.title("Satisfaction by Departure/Arrival time convenient in Business Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 4)
sns.countplot(x="Ease of Online booking", hue="satisfaction", data=business, palette=warnacuy)
plt.xlabel("Ease of Online booking")
plt.ylabel("Count")
plt.title("Satisfaction byEase of Online booking in Business Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 5)
sns.countplot(x="Gate location", hue="satisfaction", data=business, palette=warnacuy)
plt.xlabel("Gate location")
plt.ylabel("Count")
plt.title("Satisfaction by Gate location in Business Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 6)
sns.countplot(x="Food and drink", hue="satisfaction", data=business, palette=warnacuy)
plt.xlabel("Food and drink")
plt.ylabel("Count")
plt.title("Satisfaction by Food and drink in Business Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 7)
sns.countplot(x="Online boarding", hue="satisfaction", data=business, palette=warnacuy)
plt.xlabel("Online boarding")
plt.ylabel("Count")
plt.title("Satisfaction by Online boarding in Business Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 8)
sns.countplot(x="Seat comfort", hue="satisfaction", data=business, palette=warnacuy)
plt.xlabel("Seat comfort")
plt.ylabel("Count")
plt.title("Satisfaction by Seat comfort in Business Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 9)
sns.countplot(x="Inflight entertainment", hue="satisfaction", data=business, palette=warnacuy)
plt.xlabel("Inflight entertainment")
plt.ylabel("Count")
plt.title("Satisfaction by Inflight entertainment in Business Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 10)
sns.countplot(x="On-board service", hue="satisfaction", data=business, palette=warnacuy)
plt.xlabel("On-board service") 
plt.ylabel("Count")
plt.title("Satisfaction by On-board service in Business Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 11)
sns.countplot(x="Baggage handling", hue="satisfaction", data=business, palette=warnacuy)
plt.xlabel("Baggage handling") 
plt.ylabel("Count")
plt.title("Satisfaction by Baggage handling in Business Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 12)
sns.countplot(x="Checkin service", hue="satisfaction", data=business, palette=warnacuy)
plt.xlabel("Checkin service") 
plt.ylabel("Count")
plt.title("Satisfaction by Checkin service in Business Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 13)
sns.countplot(x="Inflight service", hue="satisfaction", data=business, palette=warnacuy)
plt.xlabel("Inflight service") 
plt.ylabel("Count")
plt.title("Satisfaction by Inflight service in Business Class")
plt.legend(title='Satisfaction')

plt.subplot(7, 2, 14)
sns.countplot(x="Cleanliness", hue="satisfaction", data=business, palette=warnacuy)
plt.xlabel("Cleanliness") 
plt.ylabel("Count")
plt.title("Satisfaction by Cleanliness in Business Class")
plt.legend(title='Satisfaction')

# %% [markdown]
# ## Overral Solutions
# Dari table tersebut rata-rata tidak puas dari berbagai fasiltas yang mungkin fasilitas maskapai yang dimiliki kurang nyaman. Kita bisa membandingkan kepuasan penumpang dari 3 kelas terhadap fasilitas dan layananya yang sangat berbeda jauh. Analyst bisa merekomendasikan Monitoring dan evaluasi fasilitas dan pelayanan yang dimiliki di kelas Economy dan Economy Plus. Lalu ditingkatkan fasilitas dan pelayanannya
